# %%
# 9) Data Visualization II
# 1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for
# distribution of age with respect to each gender along with the information about whether
# they survived or not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the inbuilt Titanic dataset from Seaborn
titanic = sns.load_dataset('titanic')

# Display the first few rows of the dataset
print("Dataset Overview:")
print(titanic.head())

# Check for missing values in the 'age' column
print("\nMissing Values in 'age':")
print(titanic['age'].isnull().sum())

# Drop rows with missing 'age' values
titanic_cleaned = titanic.dropna(subset=['age'])

# Create a box plot for the distribution of age by gender and survival status
plt.figure(figsize=(12, 6))
sns.boxplot(data=titanic_cleaned, x='sex', y='age', hue='survived', palette='Set2')

# Add labels and title to the plot
plt.title('Box Plot of Age Distribution by Gender and Survival Status', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Dataset Overview:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Missing Values in 'age':
# 177

# %% [markdown]
# 📚 SHORT THEORY
# 1. Titanic Dataset
# Famous dataset with data about Titanic passengers.
#
# Columns like 'sex', 'age', 'survived', etc.
#
# ‘survived’: 0 = No, 1 = Yes.
#
# 2. Box Plot
# A box plot shows the distribution of a numeric variable (like age).
#
# It highlights:
#
# Median (middle line inside box)
#
# 1st quartile (Q1), 3rd quartile (Q3) (edges of box)
#
# Minimum and Maximum (whiskers)
#
# Outliers (points outside whiskers)
#
# 3. Goal of the Task
# Plot age distribution by gender (sex) and whether they survived or not (survived).
#
# Help understand survival patterns based on age and gender.
#
# 🧠 LINE-BY-LINE CODE EXPLANATION
# Step 1: Import Libraries
# python
# Copy
# Edit
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# Seaborn for visualizations.
#
# Matplotlib for advanced plotting options.
#
# Pandas for data handling.
#
# Step 2: Load Titanic Dataset
# python
# Copy
# Edit
# titanic = sns.load_dataset('titanic')
# Load the Titanic dataset that comes built-in with Seaborn.
#
# Step 3: View Dataset
# python
# Copy
# Edit
# print("Dataset Overview:")
# print(titanic.head())
# Print first 5 rows to see the structure of data: columns like sex, age, survived, etc.
#
# Step 4: Check Missing Values
# python
# Copy
# Edit
# print("\nMissing Values in 'age':")
# print(titanic['age'].isnull().sum())
# Check how many passengers have missing age values (because missing values can cause problems in plotting).
#
# Step 5: Remove Missing Ages
# python
# Copy
# Edit
# titanic_cleaned = titanic.dropna(subset=['age'])
# Drop rows where age is missing.
#
# Create a clean dataset called titanic_cleaned.
#
# Step 6: Create Box Plot
# python
# Copy
# Edit
# plt.figure(figsize=(12, 6))
# sns.boxplot(data=titanic_cleaned, x='sex', y='age', hue='survived', palette='Set2')
# Create a figure of size 12x6 inches.
#
# Draw a boxplot:
#
# x-axis: gender (sex)
#
# y-axis: age
#
# hue: separate by survival status (different colors for survived/not survived).
#
# palette='Set2': sets soft colors.
#
# Step 7: Customize Plot
# python
# Copy
# Edit
# plt.title('Box Plot of Age Distribution by Gender and Survival Status', fontsize=16)
# plt.xlabel('Gender', fontsize=12)
# plt.ylabel('Age', fontsize=12)
# plt.legend(title='Survived', labels=['No', 'Yes'])
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# Add title, x and y labels.
#
# Set legend to show ‘No’ (0) and ‘Yes’ (1) for survival.
#
# Add a dashed grid for the y-axis to improve readability.
#
# Step 8: Show the Plot
# python
# Copy
# Edit
# plt.show()
# Display the final box plot.
#
# ✨ OBSERVATIONS (Inference)
# After you plot the graph, you can write:
#
# Females had higher survival rates compared to males.
#
# The median age for survivors is lower among males compared to non-survivors.
#
# Many young children also survived (you might see younger age outliers who survived).
#
# Older passengers had lower survival chances overall.
#
# 🧡 Summary:
# Data Cleaning: Removed missing ages.
#
# Box Plot: Showed how age and gender relate to survival.
#
# Insights: Females and younger passengers had better survival rates.
